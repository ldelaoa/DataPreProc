# %%
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np
from skimage import morphology
import os
import random
from LookFiles import *
import pandas as pd
from skimage.measure import label,regionprops
import logging

# %%
#root = "Z:/Projectline_modelling_lung_cancer/Nii_Processed/"
root = "//zkh/appdata/RTDicom/Projectline_modelling_lung_cancer/Users/Luis/CT_ITV_GTV_XBP_Nii/"

# %%
folderToLook = "//zkh/appdata/RTDicom/Projectline_modelling_lung_cancer/Users/Luis/CT_ITV_GTV_XBP_Nii/"
PxList_file  = "//zkh/appdata/RTDicom/Projectline_modelling_lung_cancer/Users/Luis/ListsOfPatients/PxSelectionforDCM2Nii.txt"
with open(PxList_file, 'r') as file:
    PxList = [line.rstrip() for line in file]
print(len(PxList))
# Out:
# 861

# %%
GTVcreated = ["GTVp_created", "GTVn_created",]
ITVcreated = ["ITVp_created", "ITVn_created",]

# %%
def  FormatToSave(itvTot,itvTumor,itvNodes,gtvTot,gtvTumor,gtvNodes):
    if len(itvTot)==0: itvTot=False
    else: itvTot=itvTot[0].split("\\")[-1]
    if len(gtvTot)==0: gtvTot=False
    else: gtvTot=gtvTot[0].split("\\")[-1]

    if len(itvTumor)==0: itvTumor=False
    else: itvTumor=itvTumor[0].split("\\")[-1]
    if len(gtvTumor)==0: gtvTumor=False
    else: gtvTumor=gtvTumor[0].split("\\")[-1]

    if len(itvNodes)==0: itvNodes=False
    else: itvNodes=itvNodes[0].split("\\")[-1]
    if len(gtvNodes)==0: gtvNodes=False
    else: gtvNodes=gtvNodes[0].split("\\")[-1]
    return  itvTot,itvTumor,itvNodes,gtvTot,gtvTumor,gtvNodes

# %%
logger = logging.getLogger('TumorAlgebra_Log')
logger.setLevel(logging.DEBUG)

handler = logging.FileHandler('TumorAlgebra_Log.log')
handler.setLevel(logging.DEBUG)

logger.addHandler(handler)

# %%
header  = ["PxID","ITV Tot","ITV Tot Vol","ITVp","ITVpV Vol","ITVn","ITVn Vol","GTV Tot","GTV Tot Vol","GTVp","GTVp Vol","GTVn","GTVn Vol"]

# %%
def CheckVolumeStruct(struct_path):
    if len(struct_path)==0:
        return None
    struct_np  = nib.load(struct_path[0]).get_fdata()    
    struct_sum = np.sum(struct_np)
    return struct_sum

def SentPathsToCheckVol(itvTot,itvTumor,itvNodes,gtvTot,gtvTumor,gtvNodes):
    itvTot_vol = CheckVolumeStruct(itvTot)
    itvTumor_vol = CheckVolumeStruct(itvTumor)
    itvNodes_vol = CheckVolumeStruct(itvNodes)
    
    gtvTot_vol = CheckVolumeStruct(gtvTot)
    gtvTumor_vol = CheckVolumeStruct(gtvTumor)
    gtvNodes_vol = CheckVolumeStruct(gtvNodes)
    
    return itvTot_vol,itvTumor_vol,itvNodes_vol,gtvTot_vol,gtvTumor_vol,gtvNodes_vol

# %%
rows = []
rowsCreated = []
for currPx in PxList:
    itvCreated_bool,gtvCreated_bool = False,False
    for root, dirs, files in os.walk(os.path.join(folderToLook,currPx), topdown=True):
        for f in files:
            if any(label_tt in f for label_tt in GTVcreated):                
                gtvCreated_bool = True
            if any(label_tt in f for label_tt in ITVcreated):
                itvCreated_bool = True
    if gtvCreated_bool or itvCreated_bool:
        _, _,_,itvTot,itvTumor,itvNodes,gtvTot,gtvTumor,gtvNodes,_,_,_,_,_,_,_,_,_,_,_ = LookFilesNiiRaw(os.path.join(folderToLook, currPx),logger)
        
        itvTot_name,itvTumor_name,itvNodes_name,gtvTot_name,gtvTumor_name,gtvNodes_name = FormatToSave(itvTot,itvTumor,itvNodes,gtvTot,gtvTumor,gtvNodes)
        itvTot_vol,itvTumor_vol,itvNodes_vol,gtvTot_vol,gtvTumor_vol,gtvNodes_vol = SentPathsToCheckVol(itvTot,itvTumor,itvNodes,gtvTot,gtvTumor,gtvNodes)
        rows.append([currPx,itvTot_name,itvTot_vol,itvTumor_name,itvTumor_vol,itvNodes_name,itvNodes_vol,gtvTot_name,gtvTot_vol,gtvTumor_name,gtvTumor_vol,gtvNodes_name,gtvNodes_vol])
# Out:
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 9
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 7 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 1 bp60 1 bp70 0 bp80 0 bp90 0 bp100 1
# Total Files in Px Folder 9
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 12
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 2 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 2 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 2 bp70 1 bp80 1 bp90 2 bp100 1
# Total Files in Px Folder 20
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 0 ITVtum 0 ITVnod 0
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 1 bp60 0 bp70 0 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 9
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 1 bp60 1 bp70 0 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 11
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 1 bp60 0 bp70 0 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 11
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 2 bp70 0 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 11
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 1 bp60 0 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 12
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 4 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 11
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 3 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 12
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 4 bp70 0 bp80 0 bp90 0 bp100 1
# Total Files in Px Folder 10
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 4 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 13
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 4 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 10
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 10
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 0 GTVtum 0 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 1 bp60 0 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 9
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 1 bp60 2 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 10
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 1 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 13
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 2 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 10
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 1 bp60 3 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 11
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 1 bp60 2 bp70 0 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 10
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 0 ITVtum 0 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 3 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 10
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 3 bp70 0 bp80 0 bp90 0 bp100 1
# Total Files in Px Folder 6
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 3 bp70 0 bp80 1 bp90 0 bp100 0
# Total Files in Px Folder 10
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 0 ITVtum 0 ITVnod 0
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 0 ITVtum 0 ITVnod 0
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 1 bp60 1 bp70 0 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 8
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 4 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 9
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 1 bp60 0 bp70 0 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 10
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 2 bp60 0 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 8
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 0 bp60 0 bp70 0 bp80 1 bp90 0 bp100 0
# Total Files in Px Folder 12
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 7 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 0 bp60 6 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 13
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 11
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 0 bp60 6 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 13
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 0 ITVnod 0
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 7 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 12
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 0 bp30 0 bp40 1
# BP50 0 bp60 5 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 11
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 0 bp60 6 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 12
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 0 ITVtum 0 ITVnod 0
# GTVtot 1 GTVtum 0 GTVnod 2
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 7 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 12
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 7 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 7 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 0 bp60 6 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 13
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 0 bp60 6 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 12
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 7 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 0 bp60 5 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 12
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 10
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 7 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 7 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 8
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 0 bp60 6 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 11
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 0 bp60 6 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 11
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 0 bp60 6 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 13
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 7 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 8
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 0 ITVnod 0
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 7 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 12
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 7 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 0 bp60 6 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 12
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 8 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 7 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 7 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 7 bp70 1 bp80 0 bp90 1 bp100 1
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 7 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 12
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 0 bp20 1 bp30 0 bp40 1
# BP50 1 bp60 7 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 1 bp60 0 bp70 0 bp80 0 bp90 0 bp100 1
# Total Files in Px Folder 11
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 1 bp60 0 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 9
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 2 bp70 0 bp80 0 bp90 0 bp100 1
# Total Files in Px Folder 9
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 1 bp60 0 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 10
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 9
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 11
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 8
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 9
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 9
# ACCT 0 PET 0
# PlanCT 0
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 11
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 9
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 11
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 2 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 2 bp70 1 bp80 1 bp90 2 bp100 1
# Total Files in Px Folder 20
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 2 bp70 0 bp80 0 bp90 0 bp100 1
# Total Files in Px Folder 7
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 6
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 9
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 0 bp100 1
# Total Files in Px Folder 9
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 6
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 9
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 11
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 2 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 1
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 2 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 1
# Total Files in Px Folder 20
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 2 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 2 bp70 1 bp80 1 bp90 2 bp100 1
# Total Files in Px Folder 22
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 0 ITVnod 0
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 2 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 1
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 2 bp70 0 bp80 0 bp90 0 bp100 1
# Total Files in Px Folder 11
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 2 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 1
# Total Files in Px Folder 20
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 2 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 8
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 2 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 1
# Total Files in Px Folder 20
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 2 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 1
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 2 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 1
# Total Files in Px Folder 20
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 2 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 1
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 0 bp10 0 bp20 0 bp30 0 bp40 0
# BP50 0 bp60 1 bp70 0 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 9
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 2 bp10 2 bp20 2 bp30 2 bp40 2
# BP50 2 bp60 2 bp70 2 bp80 2 bp90 2 bp100 0
# Total Files in Px Folder 24
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 2 bp10 2 bp20 2 bp30 2 bp40 2
# BP50 2 bp60 2 bp70 2 bp80 2 bp90 2 bp100 0
# Total Files in Px Folder 27
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 0 GTVtum 0 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 11
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 2 GTVnod 2
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 2 ITVtum 1 ITVnod 1
# GTVtot 2 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 2 GTVnod 2
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 2 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 2 GTVnod 2
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 0 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 2
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 20
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 2
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 19
# ACCT 0 PET 0
# PlanCT 2
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 2 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 20
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 2 bp10 1 bp20 0 bp30 1 bp40 1
# BP50 0 bp60 1 bp70 1 bp80 0 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 2
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# ...
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 2
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 2 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 2 bp10 2 bp20 2 bp30 2 bp40 2
# BP50 2 bp60 2 bp70 2 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 25
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 0 GTVnod 0
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 13
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 2 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 2 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 14
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 15
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 2
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 18
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 0 bp90 0 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 0 ITVtum 1 ITVnod 1
# GTVtot 0 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 16
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17
# ACCT 0 PET 0
# PlanCT 1
# ITVtot 1 ITVtum 1 ITVnod 1
# GTVtot 1 GTVtum 1 GTVnod 1
# BP0 1 bp10 1 bp20 1 bp30 1 bp40 1
# BP50 1 bp60 1 bp70 1 bp80 1 bp90 1 bp100 0
# Total Files in Px Folder 17

# %%
df = pd.DataFrame(rows, columns=header)
df
# Out:
#         PxID      ITV Tot  ITV Tot Vol                 ITVp      ITVpV Vol  \
# 0    4291861   ITV.nii.gz       4833.0  ITVp_created.nii.gz    4832.999999
# 1    3327503   ITV.nii.gz      19764.0      ITVtumor.nii.gz   20219.000000
# 2    4693524  IGTV.nii.gz      33787.0  ITVp_created.nii.gz   33786.999992
# 3    6184000  IGTV.nii.gz      61681.0         IGTVp.nii.gz   38821.000000
# 4    6163057  ITV1.nii.gz       9747.0      ITVtumor.nii.gz    6359.000000
# ..       ...          ...          ...                  ...            ...
# 526  1034109  IGTV.nii.gz     139062.0         IGTVp.nii.gz  138115.000000
# 527  2385186  IGTV.nii.gz     361239.0         IGTVp.nii.gz  320252.000000
# 528  3409329        False          NaN         IGTVp.nii.gz   15422.000000
# 529  9312325  IGTV.nii.gz      48155.0         IGTVp.nii.gz   37371.000000
# 530  7608217  IGTV.nii.gz       9672.0  ITVp_created.nii.gz    9671.999998
#
#                     ITVn      ITVn Vol     GTV Tot  GTV Tot Vol  \
# 0    ITVn_created.nii.gz      0.000000  GTV.nii.gz       3168.0
# 1    ITVn_created.nii.gz   -455.007324  GTV.nii.gz      19764.0
# 2    ITVn_created.nii.gz      0.000000  GTV.nii.gz      33787.0
# 3    ITVn_created.nii.gz  22859.999995  GTV.nii.gz      55158.0
# 4    ITVn_created.nii.gz   3387.999999       False          NaN
# ..                   ...           ...         ...          ...
# 526  ITVn_created.nii.gz    947.000000  GTV.nii.gz     101897.0
# 527  ITVn_created.nii.gz  40986.999990  GTV.nii.gz     290890.0
# 528  ITVn_created.nii.gz      0.000000       False          NaN
# 529  ITVn_created.nii.gz  11679.844416  GTV.nii.gz      38652.0
# 530  ITVn_created.nii.gz      0.000000  GTV.nii.gz       6338.0
#
#                     GTVp       GTVp Vol                 GTVn      GTVn Vol
# 0    GTVp_created.nii.gz    3167.999999  GTVn_created.nii.gz      0.000000
# 1        GTVtumor.nii.gz   20219.000000  GTVn_created.nii.gz   -455.007324
# 2    GTVtumor_exp.nii.gz   33787.000000  GTVn_created.nii.gz      0.000000
# 3            GTVp.nii.gz   35634.000000          GTVn.nii.gz  19780.000000
# 4        GTVtumor.nii.gz    2914.000000  GTVn_created.nii.gz      0.000000
# ..                   ...            ...                  ...           ...
# 526          GTVp.nii.gz  101341.000000          GTVn.nii.gz    631.000000
# 527          GTVp.nii.gz  259817.000000          GTVn.nii.gz  31551.000000
# 528          GTVp.nii.gz    9252.000000  GTVn_created.nii.gz      0.000000
# 529          GTVp.nii.gz   29610.000000          GTVn.nii.gz   9162.000000
# 530          GTVp.nii.gz    6133.000000          GTVn.nii.gz    220.000000
#
# [531 rows x 13 columns]

# %%
path2save = "//zkh/appdata/RTDicom/Projectline_modelling_lung_cancer/Users/Luis/CSVs/"
df.to_csv(path2save+'NiiTumorVolumes_wAlgebra_v1.csv', index=False)

# %%
def CheckBlobs(struct_np):
    labeled_np = label(struct_np)
    regions_3d = regionprops(labeled_np)
    numBlobs = len(regions_3d)
    list_of_volume = [region.area_filled for region in regions_3d]
    return numBlobs,list_of_volume

# %%
def largestRatio(struct_np):
    ratioVal_x,ratioVal_y,ratioVal_z = 0,0,0
    listRatios_x,listRatios_y,listRatios_z = [],[],[]
    #Z
    maxRatio = 0
    for i in range(struct_np.shape[-1]):
        if np.sum(struct_np[:,:,i])>0:
            currPosSum = np.sum(struct_np[:,:,i])
            currTotSum = struct_np.shape[0]*struct_np.shape[1]
            currRatio = currPosSum/currTotSum
            listRatios_z.append(currRatio)
            if currRatio>maxRatio:
                maxRatio = currRatio
                maxSlide = i
    ratioVal_z = maxRatio
    maxSlide_z = maxSlide
    #Y
    maxRatio = 0
    for i in range(struct_np.shape[-2]):
        if np.sum(struct_np[:,i,:])>0:
            currPosSum = np.sum(struct_np[:,i,:])
            currTotSum = struct_np.shape[0]*struct_np.shape[2]
            currRatio = currPosSum/currTotSum
            listRatios_y.append(currRatio)
            if currRatio>maxRatio:
                maxRatio = currRatio
                maxSlide = i
    ratioVal_y = maxRatio
    maxSlide_y = maxSlide
    #X
    maxRatio = 0
    for i in range(struct_np.shape[-3]):
        if np.sum(struct_np[i,:,:])>0:
            currPosSum = np.sum(struct_np[i,:,:])
            currTotSum = struct_np.shape[1]*struct_np.shape[2]
            currRatio = currPosSum/currTotSum
            listRatios_x.append(currRatio)
            if currRatio>maxRatio:
                maxRatio = currRatio
                maxSlide = i
    ratioVal_x = maxRatio
    maxSlide_x = maxSlide

    return listRatios_x,listRatios_y,listRatios_z,ratioVal_x,ratioVal_y,ratioVal_z,maxSlide_x,maxSlide_y,maxSlide_z

# %%
asdasdsad
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 asdasdsad
#
# NameError: name 'asdasdsad' is not defined

# %%
listOfShapes_X,listOfShapes_Y,listOfShapes_Z = [],[],[]
gtvSums_list = []
listMaxRatios = []
listAvgRatios = []
listMedianRatios = []
okPx,errorPx = [],[]
listBlobVolumes = []
listNumBlobs = []

for Px in PxList:
    planCT_list,planCTLung_list,bp50_list,bp50Lung_list,gtv_list,itv_list = LookFiles_Snapshot(root+Px)
    flagOkPx = False
    #ReadImages
    if False:
        ct_np  = nib.load(planCT_list[0]).get_fdata()
        lung_np  = nib.load(planCTLung_list[0]).get_fdata()
        bp50_np  = nib.load(bp50_list[0]).get_fdata()
        bp50Lung_np  = nib.load(bp50Lung_list[0]).get_fdata()
        #aveLung_filled = FixHoles(lung_np)
        #bp50Lung_filled = FixHoles(bp50Lung_np)

    if len(gtv_list)>0 and len(bp50_list)>0:
        tum_np  = nib.load(gtv_list[0]).get_fdata()
        flagOkPx = True
    elif len(itv_list)>0 and len(planCT_list)>0:
        tum_np  = nib.load(itv_list[0]).get_fdata()
        flagOkPx = True
    else:
        errorPx.append(Px)
        

    if flagOkPx:
        #Calculations
        #tum_filled = FixHoles(tum_np)
        tum_filled = tum_np
        if np.sum(tum_filled)!=0:
            okPx.append(Px)
            listOfShapes_X.append(tum_filled.shape[0])
            listOfShapes_Y.append(tum_filled.shape[1])
            listOfShapes_Z.append(tum_filled.shape[2])
            gtvSums_list.append(np.sum(tum_filled))

            listRatios_x,listRatios_y,listRatios_z,ratioVal_x,ratioVal_y,ratioVal_z,maxSlide_x,maxSlide_y,maxSlide_z = largestRatio(tum_filled)
        
            listMaxRatios.append([ratioVal_x,ratioVal_y,ratioVal_z])
            listAvgRatios.append([np.mean(listRatios_x),np.mean(listRatios_y),np.mean(listRatios_z)])
            listMedianRatios.append([np.median(listRatios_x),np.median(listRatios_y),np.median(listRatios_z)])

            numBlobs,volumeBlobs = CheckBlobs(tum_filled)
            listBlobVolumes.append(volumeBlobs)
            listNumBlobs.append(numBlobs)

        else:
            errorPx.append(Px)

        
listOfUniquesShapes = [np.unique(listOfShapes_X),np.unique(listOfShapes_Y),np.unique(listOfShapes_Z)]


gtvSum_Avg = np.mean(gtvSums_list)
gtvSum_Median = np.median(gtvSums_list)
maxRatio_Avg = np.mean(listMaxRatios,0)
avgRatio_Avg = np.mean(listAvgRatios,0)
avgRatio_Med = np.median(listMedianRatios,0)

numBlobs_Avg = np.mean(listNumBlobs)
numBlobs_Med = np.median(listNumBlobs)

flatlist_Volumes = [item for sublist in listBlobVolumes for item in sublist]
volBlobs_Avg = np.mean(flatlist_Volumes)
volBlobs_Med = np.median(flatlist_Volumes)

print("Unique Shapes",listOfUniquesShapes)
print("Avg GTV Mm3",gtvSum_Avg,"in ml ",gtvSum_Avg/1000)
print("Median GTV Mm3",gtvSum_Median,"in ml ",gtvSum_Median/1000)
print("Max Ratio Avg",maxRatio_Avg*100)
print("Avg Ratio Avg",avgRatio_Avg*100)
print("Avg Ratio Median", avgRatio_Med*100)
print("Num of Px",len(PxList),"Ok",len(okPx),"err",len(errorPx))
print("Num Blobs, Avg:",numBlobs_Avg,"Median",numBlobs_Med)
print("Vol Blobs,Avg:",volBlobs_Avg,"Med",volBlobs_Med)

# %%
asd

# %%
def Screenshot(ct_np,gtv_np,middle_x,middle_y,middle_z,contourBool=True,Px2Save=None,ImageType=None):
    minHU = -1024
    maxHU = 600
    savebool = True
    #root2save= "Z:/Projectline_modelling_lung_cancer/JPEGs/Processed/V1/"
    root2save= "//zkh/appdata/RTDicom/Projectline_modelling_lung_cancer/Users/Luis/JPEGs/Nii_Processed/"
    if Px2Save is not None:
        pathToSave = os.path.join(root2save,Px2Save)
        if not(os.path.exists(pathToSave)):
            os.mkdir(pathToSave)
    
    print(middle_x,middle_y,middle_z,Px2Save,ct_np.shape,ImageType,gtv_np.shape)
    
    clipped_image = np.clip(ct_np, minHU, maxHU)
    #middle_x,middle_y,middle_z = getMiddleSlices(gtv_np)
    plt.figure(figsize=(15, 15), dpi=150)#dpi=300)
    plt.imshow(clipped_image[:,:,middle_z],cmap='gray'),plt.axis('off')#,plt.colorbar()
    plt.title("Z:"+str(middle_z))
    if contourBool:
        plt.contour(gtv_np[:,:,middle_z],linewidths=0.5,colors='r')
    if not(savebool): 
        plt.show()
    else:
        plt.savefig(pathToSave+"/"+ImageType+"_Axial.jpeg")
        plt.close()
    plt.figure(figsize=(15, 15), dpi=300)
    plt.imshow(np.rot90(clipped_image[:,middle_y,:]),cmap='gray'),plt.axis('off')#,plt.colorbar()
    plt.title("Y:"+str(middle_y))
    if contourBool:
        plt.contour(np.rot90(gtv_np[:,middle_y,:]),linewidths=0.5,colors='r')
    if not(savebool): 
        plt.show()
    else:
        plt.savefig(pathToSave+"/"+ImageType+"_Sagital.jpeg")
        plt.close()
    plt.figure(figsize=(15, 15), dpi=300)
    plt.imshow(np.rot90(clipped_image[middle_x,:,:]),cmap='gray'),plt.axis('off')#,plt.colorbar()
    plt.title("X:"+str(middle_x))
    if contourBool:
        plt.contour(np.rot90(gtv_np[middle_x,:,:]),linewidths=0.5,colors='r')
    if not(savebool): 
        plt.show()
    else:
        plt.savefig(pathToSave+"/"+ImageType+"_Coronal.jpeg")
        plt.close()

# %%
def CountSlidesPerCategory(struct_np,tumorSlide_Tresh):
    #Z
    countTum_z = 0
    countSemi_z =0
    indices_Tum_z = []
    indices_Semi_z = []
    for i in range(struct_np.shape[-1]):
        if np.sum(struct_np[:,:,i])>0:
            currRatio = np.sum(struct_np[:,:,i])/(struct_np.shape[0]*struct_np.shape[1])
            if currRatio > tumorSlide_Tresh[-1]:
                countTum_z+=1
                indices_Tum_z.append(i)
            elif currRatio > 0:
                countSemi_z+=1
                indices_Semi_z.append(i)
    #Y
    countTum_y = 0
    countSemi_y =0
    indices_Tum_y= []
    indices_Semi_y = []
    for i in range(struct_np.shape[-2]):
        if np.sum(struct_np[:,i,:])>0:
            currRatio = np.sum(struct_np[:,i,:])/(struct_np.shape[0]*struct_np.shape[2])
            if currRatio > tumorSlide_Tresh[-2]:
                countTum_y+=1
                indices_Tum_y.append(i)
            elif currRatio > 0:
                countSemi_y+=1
                indices_Semi_y.append(i)
    #X
    countTum_x = 0
    countSemi_x =0
    indices_Tum_x= []
    indices_Semi_x = []
    for i in range(struct_np.shape[-3]):
        if np.sum(struct_np[i,:,:])>0:
            currRatio = np.sum(struct_np[i,:,:])/(struct_np.shape[1]*struct_np.shape[2])
            if currRatio > tumorSlide_Tresh[-3]:
                countTum_x+=1
                indices_Tum_x.append(i)
            elif currRatio > 0:
                countSemi_x+=1
                indices_Semi_x.append(i)

    
    #return countTum_x,countTum_y,countTum_z,countSemi_x,countSemi_y,countSemi_z,
    return indices_Tum_x,indices_Tum_y,indices_Tum_z,indices_Semi_x,indices_Semi_y,indices_Semi_z

# %%
factor=.2
tumorSlide_AvgTresh = [avgRatio_Avg[0]*factor,avgRatio_Avg[1]*factor,avgRatio_Avg[2]*factor]
tumorSlide_MediTresh = [avgRatio_Med[0]*factor,avgRatio_Med[1]*factor,avgRatio_Med[2]*factor]

# %%
def FixHoles(struct_np):
    struct_np[struct_np>0] = 1
    struct_bool = morphology.binary_closing(struct_np.astype(bool))
    struct_filled = struct_bool.astype(np.uint8)
    return struct_filled

# %%
totTum_x,totTum_y,totTum_z = 0,0,0
totSemi_x,totSemi_y,totSemi_z = 0,0,0
count=0
for Px in okPx:
    planCT_list,planCTLung_list,bp50_list,bp50Lung_list,gtv_list,itv_list = LookFiles_Snapshot(root+Px)
    
    if len(gtv_list)>0:
        tum_np  = nib.load(gtv_list[0]).get_fdata()
        ct_np  = nib.load(bp50_list[0]).get_fdata()
        #tum_filled = FixHoles(tum_np)
        tum_filled = tum_np
        ContourType="GTV"
    else:
        tum_np  = nib.load(itv_list[0]).get_fdata()
        ct_np  = nib.load(planCT_list[0]).get_fdata()
        #tum_filled = FixHoles(tum_np)
        tum_filled = tum_np
        ContourType="ITV"

    #countTum_x,countTum_y,countTum_z,countSemi_x,countSemi_y,countSemi_z = CountSlidesPerCategory(tum_filled,tumorSlide_MediTresh)
    indices_Tum_x,indices_Tum_y,indices_Tum_z,indices_Semi_x,indices_Semi_y,indices_Semi_z= CountSlidesPerCategory(tum_filled,tumorSlide_MediTresh)
    
    totTum_x+=len(indices_Tum_x)
    totTum_y+=len(indices_Tum_y)
    totTum_z+=len(indices_Tum_z)

    totSemi_x+=len(indices_Semi_x)
    totSemi_y+=len(indices_Semi_y)
    totSemi_z+=len(indices_Semi_z)

    if len(indices_Tum_x)!=0: randomcTumorX = random.choice(indices_Tum_x)
    else: randomcTumorX = 0
    if len(indices_Tum_y)!=0: randomcTumorY = random.choice(indices_Tum_y)
    else: randomcTumorY = 0
    if len(indices_Tum_z)!=0: randomcTumorZ = random.choice(indices_Tum_z)
    else: randomcTumorZ = 0 

    #Screenshot(ct_np,tum_filled,randomcTumorX,randomcTumorY,randomcTumorZ,False,Px,ContourType+"TumorOff")
    Screenshot(ct_np,tum_filled,randomcTumorX,randomcTumorY,randomcTumorZ,True,Px,ContourType+"Tumor")
    
    if len(indices_Semi_x)!=0: randomcTumorX = random.choice(indices_Semi_x)
    else: randomcTumorX = 0
    if len(indices_Semi_y)!=0: randomcTumorY = random.choice(indices_Semi_y)
    else: randomcTumorY = 0
    if len(indices_Semi_z)!=0: randomcTumorZ = random.choice(indices_Semi_z)
    else: randomcTumorZ = 0 
    
    #Screenshot(ct_np,tum_filled,randomcTumorX,randomcTumorY,randomcTumorZ,False,Px,ContourType+"SemiOff")
    Screenshot(ct_np,tum_filled,randomcTumorX,randomcTumorY,randomcTumorZ,True,Px,ContourType+"SemiTumor")
    
print("Tot Tumor",totTum_x,totTum_y,totTum_z)
print("Tot SemiT",totSemi_x,totSemi_y,totSemi_z)

# %%
#1007981 - Is incorrect

# %%
indices_Tum_z
